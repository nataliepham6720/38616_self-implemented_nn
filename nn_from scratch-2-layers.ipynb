# %% [markdown]
# # 38616 - HW1: Implement a Neural Network from scratch
#
# Natalie Pham

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from typing import Optional, List, Tuple, Dict


if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
class Transform(object):
    """
    This is the base class. You do not need to change anything.
    Read the comments in this class carefully.
    """
    def __init__(self):
        """
        Initialize any parameters
        """
        pass

    def forward(self, x):
        """
        x should be passed as column vectors
        """
        pass

    def backward(self, grad_wrt_out):
        """
        Compute and save the gradients wrt the parameters for step()
        Return grad_wrt_x which will be the grad_wrt_out for previous Transform
        """
        pass

    def step(self):
        """
        Apply gradients to update the parameters
        """
        pass

    def zerograd(self):
        """
        This is used to Reset the gradients.
        Usually called before backward()
        """
        pass
    
class ReLU(Transform):
    def __init__(self):
        super(ReLU, self).__init__()

    def forward(self, x):
        """
        x shape (indim, batch_size)
        return shape (indim, batch_size)
        """
        self.x = x
        return(torch.maximum(x, torch.tensor(0.0)))

    def backward(self, grad_wrt_out):
        """
        grad_wrt_out shape (outdim, batch_size)
        """
        grad_wrt = torch.where(self.x > 0, grad_wrt_out, torch.tensor(0.0)) # np.where(x > 0, grad_wrt_out, 0)
        return(grad_wrt)
    
class LinearMap(Transform):
    def __init__(self, indim, outdim, lr=0.001):
        """
        indim: input dimension
        outdim: output dimension
        lr: learning rate
        """
        super(LinearMap, self).__init__()
        self.weights = 0.01 * torch.rand((outdim, indim), dtype=torch.float64, requires_grad=True, device=device)
        self.bias = 0.01 * torch.rand((outdim, 1), dtype=torch.float64, requires_grad=True, device=device)
        self.lr = lr


    def forward(self, x):
        """
        x shape (indim, batch_size)
        return shape (outdim, batch_size)
        """
        self.x = x
        output = torch.add(torch.matmul(self.weights, x), self.bias)
        return(output)


    def backward(self, grad_wrt_out):
        """
        grad_wrt_out shape (outdim, batch_size)
        return shape (indim, batch_size)
        """
        # compute grad_wrt_weights
        grad_wrt_weights = torch.matmul(grad_wrt_out, self.x.T)
        self.grad_wrt_weights = grad_wrt_weights
        
        # compute grad_wrt_bias
        grad_wrt_bias = torch.sum(grad_wrt_out, axis=1, keepdim=True)
        self.grad_wrt_bias = grad_wrt_bias
        
        # compute grad_wrt_input
        grad_wrt_input = torch.matmul(self.weights.T, grad_wrt_out)

        return grad_wrt_input


    def step(self):
        """
        apply gradients calculated by backward() to update the parameters
        """
        self.weights = self.weights - self.lr * self.grad_wrt_weights
        self.bias = self.bias - self.lr * self.grad_wrt_bias

    def zerograd(self):
        """
        This is used to Reset the gradients.
        Usually called before backward()
        """
        self.grad_wrt_weights = None
        self.grad_wrt_bias = None
        
class SoftmaxCrossEntropyLoss(object):
    def forward(self, logits, labels):
        """
        logits are pre-softmax scores, labels are one-hot labels of given inputs
        logits and labels are in the shape of (num_classes, batch_size)
        returns loss as a scalar (i.e. mean value of the batch_size loss)
        """
        self.logits = logits
        self.labels = labels

        exp_logits = torch.exp(self.logits - torch.max(logits, axis=0, keepdim=True).values)
        softmax = exp_logits / torch.sum(exp_logits, axis=0, keepdim=True)
        self.softmax = softmax
        
        self.loss = -torch.sum(self.labels * torch.log(self.softmax)) / logits.shape[1]
        return self.loss
    
    def backward(self):
        """
        return grad_wrt_logits shape (num_classes, batch_size)
        (don't forget to divide by batch_size because your loss is a mean)
        """
        grad_wrt_logits = -(self.labels - self.softmax) / self.labels.shape[1]
        return grad_wrt_logits
        
    
    def getAccu(self):
        """
        return accuracy here
        """        
        pred = torch.argmax(self.softmax, dim=0)
        target = torch.argmax(self.labels, dim=0)
        accuracy = torch.mean(torch.eq(pred, target).to(torch.float)) #/ self.labels.shape[0]
        return accuracy   
    
class SingleLayerMLP(Transform):
    """constructing a single layer neural network with the previous functions"""
    def __init__(self, indim, outdim, hidden_layer=100, lr=0.001):
        super(SingleLayerMLP, self).__init__()
        self.linear1 = LinearMap(indim, hidden_layer, lr)
        self.relu = ReLU()
        self.linear2 = LinearMap(hidden_layer, outdim, lr)
        self.softmax_loss = SoftmaxCrossEntropyLoss()
        
        
    def forward(self, x):
        """
        x shape (indim, batch_size)
        return the presoftmax logits shape(outdim, batch_size)
        """
        fwd_out = self.linear1.forward(x)
        fwd_out = self.relu.forward(fwd_out)
        fwd_out = self.linear2.forward(fwd_out)
        
        return fwd_out
    

    def backward(self, grad_wrt_out):
        """
        grad_wrt_out shape (outdim, batch_size)
        calculate the gradients wrt the parameters
        """
        grad_wrt_out = self.linear2.backward(grad_wrt_out)
        grad_wrt_out = self.relu.backward(grad_wrt_out)
        grad_wrt_out = self.linear1.backward(grad_wrt_out)
        
        return grad_wrt_out
    
    def step(self):
        """update model parameters"""
        self.linear1.step()
        self.linear2.step()
        
    def zerograd(self):
        """
        This is used to Reset the gradients.
        Usually called before backward()
        """
        self.linear1.zerograd()
        self.linear2.zerograd()
        
class DS(Dataset):
    def __init__(self, X: np.ndarray, Y: np.ndarray):
        self.length = len(X)
        self.X = X
        self.Y = Y

    def __getitem__(self, idx):
        x = self.X[idx, :]
        y = self.Y[idx]
        return (x, y)

    def __len__(self):
        return self.length

def labels2onehot(labels: torch.tensor):
    return torch.tensor([[i==lab for i in range(2)] for lab in labels], dtype=torch.float)

# %%
class TwoLayerMLP(Transform):
    """constructing a single layer neural network with the previous functions"""
    def __init__(self, indim, outdim, hidden_layer=100, lr=0.001):
        super(TwoLayerMLP, self).__init__()
        # first hidden layer
        self.linear1 = LinearMap(indim, hidden_layer, lr)
        self.relu = ReLU()
        self.linear2 = LinearMap(hidden_layer, hidden_layer, lr)
        # second hidden layer
        #self.linear3 = LinearMap(hidden_layer, hidden_layer, lr)
        self.relu = ReLU()
        self.linear4 = LinearMap(hidden_layer, outdim, lr)
        
        self.softmax_loss = SoftmaxCrossEntropyLoss()
        
        
    def forward(self, x):
        """
        x shape (indim, batch_size)
        return the presoftmax logits shape(outdim, batch_size)
        """
        # first hidden layer
        fwd_out = self.linear1.forward(x)
        fwd_out = self.relu.forward(fwd_out)
        fwd_out = self.linear2.forward(fwd_out)
        # second hidden layer
        #fwd_out = self.linear3.forward(fwd_out)
        fwd_out = self.relu.forward(fwd_out)
        fwd_out = self.linear4.forward(fwd_out)
        
        return fwd_out
    

    def backward(self, grad_wrt_out):
        """
        grad_wrt_out shape (outdim, batch_size)
        calculate the gradients wrt the parameters
        """
        # second hidden layer
        grad_wrt_out = self.linear4.backward(grad_wrt_out)
        grad_wrt_out = self.relu.backward(grad_wrt_out)
        #grad_wrt_out = self.linear3.backward(grad_wrt_out)
        # first hidden layer
        grad_wrt_out = self.linear2.backward(grad_wrt_out)
        grad_wrt_out = self.relu.backward(grad_wrt_out)
        grad_wrt_out = self.linear1.backward(grad_wrt_out)
        
        return grad_wrt_out
    
    def step(self):
        """update model parameters"""
        self.linear1.step()
        self.linear2.step()
        #self.linear3.step()
        self.linear4.step()
        
    def zerograd(self):
        """
        This is used to Reset the gradients.
        Usually called before backward()
        """
        self.linear1.zerograd()
        self.linear2.zerograd()
        #self.linear3.zerograd()
        self.linear4.zerograd()

# %%
if __name__ == "__main__":
    """The dataset loaders were provided for you.
    You need to implement your own training process.
    You need plot the loss and accuracies during the training process and test process. 
    """

    indim = 10
    outdim = 2
    hidden_dim = 100
    lr = 0.01
    batch_size = 64
    epochs = 300

    #dataset
    Xtrain = np.loadtxt("data/XTrain.txt", delimiter="\t")
    Ytrain = np.loadtxt("data/yTrain.txt", delimiter="\t").astype(int)
    m1, n1 = Xtrain.shape
    print(m1, n1)
    train_ds = DS(Xtrain, Ytrain)
    train_loader = DataLoader(train_ds, batch_size=batch_size)

    Xtest = np.loadtxt("data/XTest.txt", delimiter="\t")
    Ytest = np.loadtxt("data/yTest.txt", delimiter="\t").astype(int)
    m2, n2 = Xtest.shape
    print(m1, n2)
    test_ds = DS(Xtest, Ytest)
    test_loader = DataLoader(test_ds, batch_size=batch_size)

    #construct the model
    model = TwoLayerMLP(indim, outdim, hidden_dim, lr)

    # Define the loss function
    loss_fnc = SoftmaxCrossEntropyLoss()
    
    #construct the training process
    train_losses, train_accs, test_losses, test_accs = [], [], [], []
    for epoch in range(epochs):
        total_train_loss = 0
        total_train_acc = 0 
        total_test_loss = 0
        total_test_acc = 0
        
        train_samples = 0
        test_samples = 0
        # Train the model
        for x, y in train_loader:
            x = torch.tensor(x).T 
            y = torch.tensor(labels2onehot(y))
            train_samples += x.shape[1]
            
            # get train loss and accuracy
            train_loss = loss_fnc.forward(model.forward(x), y.T)
            total_train_loss += train_loss * x.shape[1]
            train_acc = loss_fnc.getAccu()
            total_train_acc += train_acc * x.shape[1]
            
            # backpropagation
            grad_wrt_out = loss_fnc.backward()
            model.backward(grad_wrt_out)
            model.step()
            
            # zero the gradients
            model.zerograd()
        
        # print(train_samples)
        avg_train_loss = total_train_loss / train_samples 
        train_losses.append(avg_train_loss)
        avg_train_acc = total_train_acc / train_samples 
        train_accs.append(avg_train_acc)
        
        
        # Validate the model
        for x, y in test_loader:
            x = torch.tensor(x).T 
            y = torch.tensor(labels2onehot(y))
            test_samples += x.shape[1]
            
            # get test loss and accuracy
            test_loss = loss_fnc.forward(model.forward(x), y.T)
            total_test_loss += test_loss * x.shape[1]
            test_acc = loss_fnc.getAccu()
            total_test_acc += test_acc * x.shape[1]
            
            
        avg_test_loss = total_test_loss / test_samples
        test_losses.append(avg_test_loss)
        avg_test_acc = total_test_acc / test_samples 
        test_accs.append(avg_test_acc)
        
        print(f"Epoch {epoch+1}: Train Loss={avg_train_loss:.4f}, Train Acc={avg_train_acc:.4f}, Test Loss={avg_test_loss:.4f}, Test Acc={avg_test_acc:.4f}")
# Out:
# 500 10
# 500 10
# Epoch 1: Train Loss=0.6931, Train Acc=0.5600, Test Loss=0.6931, Test Acc=0.5000
# Epoch 2: Train Loss=0.6931, Train Acc=0.5440, Test Loss=0.6931, Test Acc=0.5000
# Epoch 3: Train Loss=0.6931, Train Acc=0.5200, Test Loss=0.6930, Test Acc=0.5000
# C:\Users\thanh\Anaconda3\envs\CMU\lib\site-packages\ipykernel_launcher.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# C:\Users\thanh\Anaconda3\envs\CMU\lib\site-packages\ipykernel_launcher.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# C:\Users\thanh\Anaconda3\envs\CMU\lib\site-packages\ipykernel_launcher.py:74: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# C:\Users\thanh\Anaconda3\envs\CMU\lib\site-packages\ipykernel_launcher.py:75: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Epoch 4: Train Loss=0.6930, Train Acc=0.5380, Test Loss=0.6930, Test Acc=0.5000
# Epoch 5: Train Loss=0.6930, Train Acc=0.5380, Test Loss=0.6930, Test Acc=0.5000
# Epoch 6: Train Loss=0.6929, Train Acc=0.5120, Test Loss=0.6929, Test Acc=0.5000
# Epoch 7: Train Loss=0.6929, Train Acc=0.5180, Test Loss=0.6929, Test Acc=0.5000
# Epoch 8: Train Loss=0.6929, Train Acc=0.5240, Test Loss=0.6929, Test Acc=0.5000
# Epoch 9: Train Loss=0.6928, Train Acc=0.5200, Test Loss=0.6928, Test Acc=0.5000
# Epoch 10: Train Loss=0.6928, Train Acc=0.5120, Test Loss=0.6928, Test Acc=0.5000
# Epoch 11: Train Loss=0.6928, Train Acc=0.5000, Test Loss=0.6928, Test Acc=0.5000
# Epoch 12: Train Loss=0.6927, Train Acc=0.5000, Test Loss=0.6927, Test Acc=0.5000
# Epoch 13: Train Loss=0.6927, Train Acc=0.5000, Test Loss=0.6927, Test Acc=0.5000
# Epoch 14: Train Loss=0.6926, Train Acc=0.5000, Test Loss=0.6926, Test Acc=0.5000
# Epoch 15: Train Loss=0.6926, Train Acc=0.5000, Test Loss=0.6926, Test Acc=0.5000
# Epoch 16: Train Loss=0.6925, Train Acc=0.5000, Test Loss=0.6926, Test Acc=0.5000
# Epoch 17: Train Loss=0.6925, Train Acc=0.5000, Test Loss=0.6925, Test Acc=0.5000
# Epoch 18: Train Loss=0.6924, Train Acc=0.5000, Test Loss=0.6925, Test Acc=0.5000
# Epoch 19: Train Loss=0.6924, Train Acc=0.5000, Test Loss=0.6924, Test Acc=0.5000
# Epoch 20: Train Loss=0.6923, Train Acc=0.5000, Test Loss=0.6924, Test Acc=0.5000
# Epoch 21: Train Loss=0.6923, Train Acc=0.5000, Test Loss=0.6923, Test Acc=0.5000
# Epoch 22: Train Loss=0.6922, Train Acc=0.5000, Test Loss=0.6922, Test Acc=0.5000
# Epoch 23: Train Loss=0.6921, Train Acc=0.5000, Test Loss=0.6922, Test Acc=0.5000
# Epoch 24: Train Loss=0.6921, Train Acc=0.5000, Test Loss=0.6921, Test Acc=0.5000
# Epoch 25: Train Loss=0.6920, Train Acc=0.5000, Test Loss=0.6921, Test Acc=0.5000
# Epoch 26: Train Loss=0.6919, Train Acc=0.5000, Test Loss=0.6920, Test Acc=0.5000
# Epoch 27: Train Loss=0.6918, Train Acc=0.5000, Test Loss=0.6919, Test Acc=0.5000
# Epoch 28: Train Loss=0.6917, Train Acc=0.5000, Test Loss=0.6918, Test Acc=0.5000
# Epoch 29: Train Loss=0.6917, Train Acc=0.5000, Test Loss=0.6918, Test Acc=0.5000
# Epoch 30: Train Loss=0.6916, Train Acc=0.5000, Test Loss=0.6917, Test Acc=0.5000
# Epoch 31: Train Loss=0.6915, Train Acc=0.5000, Test Loss=0.6916, Test Acc=0.5000
# Epoch 32: Train Loss=0.6914, Train Acc=0.5000, Test Loss=0.6915, Test Acc=0.5000
# Epoch 33: Train Loss=0.6913, Train Acc=0.5000, Test Loss=0.6914, Test Acc=0.5000
# Epoch 34: Train Loss=0.6911, Train Acc=0.5000, Test Loss=0.6913, Test Acc=0.5000
# Epoch 35: Train Loss=0.6910, Train Acc=0.5000, Test Loss=0.6912, Test Acc=0.5000
# Epoch 36: Train Loss=0.6909, Train Acc=0.5000, Test Loss=0.6910, Test Acc=0.5000
# Epoch 37: Train Loss=0.6908, Train Acc=0.5000, Test Loss=0.6909, Test Acc=0.5000
# Epoch 38: Train Loss=0.6906, Train Acc=0.5000, Test Loss=0.6908, Test Acc=0.5000
# Epoch 39: Train Loss=0.6905, Train Acc=0.5000, Test Loss=0.6907, Test Acc=0.5000
# Epoch 40: Train Loss=0.6903, Train Acc=0.5000, Test Loss=0.6905, Test Acc=0.5000
# Epoch 41: Train Loss=0.6901, Train Acc=0.5000, Test Loss=0.6904, Test Acc=0.5000
# Epoch 42: Train Loss=0.6900, Train Acc=0.5000, Test Loss=0.6902, Test Acc=0.5000
# Epoch 43: Train Loss=0.6898, Train Acc=0.5000, Test Loss=0.6900, Test Acc=0.5000
# Epoch 44: Train Loss=0.6896, Train Acc=0.5000, Test Loss=0.6898, Test Acc=0.5000
# Epoch 45: Train Loss=0.6894, Train Acc=0.5000, Test Loss=0.6897, Test Acc=0.5000
# Epoch 46: Train Loss=0.6892, Train Acc=0.5180, Test Loss=0.6895, Test Acc=0.5000
# Epoch 47: Train Loss=0.6889, Train Acc=0.5280, Test Loss=0.6892, Test Acc=0.5000
# Epoch 48: Train Loss=0.6887, Train Acc=0.5280, Test Loss=0.6890, Test Acc=0.5000
# Epoch 49: Train Loss=0.6884, Train Acc=0.5280, Test Loss=0.6888, Test Acc=0.5000
# Epoch 50: Train Loss=0.6881, Train Acc=0.5300, Test Loss=0.6885, Test Acc=0.5000
# Epoch 51: Train Loss=0.6878, Train Acc=0.5320, Test Loss=0.6883, Test Acc=0.5000
# Epoch 52: Train Loss=0.6875, Train Acc=0.5640, Test Loss=0.6880, Test Acc=0.5000
# Epoch 53: Train Loss=0.6872, Train Acc=0.5760, Test Loss=0.6877, Test Acc=0.5000
# Epoch 54: Train Loss=0.6869, Train Acc=0.6240, Test Loss=0.6873, Test Acc=0.5000
# Epoch 55: Train Loss=0.6865, Train Acc=0.6400, Test Loss=0.6870, Test Acc=0.5000
# Epoch 56: Train Loss=0.6861, Train Acc=0.6960, Test Loss=0.6866, Test Acc=0.5000
# Epoch 57: Train Loss=0.6857, Train Acc=0.7080, Test Loss=0.6863, Test Acc=0.8400
# Epoch 58: Train Loss=0.6853, Train Acc=0.7540, Test Loss=0.6859, Test Acc=0.8550
# Epoch 59: Train Loss=0.6848, Train Acc=0.7660, Test Loss=0.6854, Test Acc=0.8650
# Epoch 60: Train Loss=0.6843, Train Acc=0.8640, Test Loss=0.6850, Test Acc=0.8700
# Epoch 61: Train Loss=0.6838, Train Acc=0.8760, Test Loss=0.6845, Test Acc=0.8750
# Epoch 62: Train Loss=0.6833, Train Acc=0.8860, Test Loss=0.6840, Test Acc=0.8700
# Epoch 63: Train Loss=0.6827, Train Acc=0.8920, Test Loss=0.6834, Test Acc=0.8800
# Epoch 64: Train Loss=0.6821, Train Acc=0.8940, Test Loss=0.6828, Test Acc=0.8850
# Epoch 65: Train Loss=0.6814, Train Acc=0.9020, Test Loss=0.6822, Test Acc=0.8850
# Epoch 66: Train Loss=0.6807, Train Acc=0.9080, Test Loss=0.6815, Test Acc=0.8950
# Epoch 67: Train Loss=0.6800, Train Acc=0.9100, Test Loss=0.6808, Test Acc=0.9000
# Epoch 68: Train Loss=0.6792, Train Acc=0.9100, Test Loss=0.6801, Test Acc=0.9050
# Epoch 69: Train Loss=0.6783, Train Acc=0.9120, Test Loss=0.6793, Test Acc=0.9100
# Epoch 70: Train Loss=0.6774, Train Acc=0.9160, Test Loss=0.6784, Test Acc=0.9100
# Epoch 71: Train Loss=0.6765, Train Acc=0.9220, Test Loss=0.6775, Test Acc=0.9150
# Epoch 72: Train Loss=0.6755, Train Acc=0.9240, Test Loss=0.6766, Test Acc=0.9150
# Epoch 73: Train Loss=0.6744, Train Acc=0.9240, Test Loss=0.6755, Test Acc=0.9150
# Epoch 74: Train Loss=0.6732, Train Acc=0.9220, Test Loss=0.6744, Test Acc=0.9150
# Epoch 75: Train Loss=0.6720, Train Acc=0.9220, Test Loss=0.6733, Test Acc=0.9100
# Epoch 76: Train Loss=0.6707, Train Acc=0.9260, Test Loss=0.6720, Test Acc=0.9100
# Epoch 77: Train Loss=0.6693, Train Acc=0.9320, Test Loss=0.6707, Test Acc=0.9100
# Epoch 78: Train Loss=0.6678, Train Acc=0.9340, Test Loss=0.6693, Test Acc=0.9150
# Epoch 79: Train Loss=0.6662, Train Acc=0.9360, Test Loss=0.6677, Test Acc=0.9150
# Epoch 80: Train Loss=0.6645, Train Acc=0.9360, Test Loss=0.6661, Test Acc=0.9150
# Epoch 81: Train Loss=0.6627, Train Acc=0.9400, Test Loss=0.6643, Test Acc=0.9150
# Epoch 82: Train Loss=0.6607, Train Acc=0.9440, Test Loss=0.6625, Test Acc=0.9150
# Epoch 83: Train Loss=0.6586, Train Acc=0.9440, Test Loss=0.6605, Test Acc=0.9250
# Epoch 84: Train Loss=0.6564, Train Acc=0.9460, Test Loss=0.6583, Test Acc=0.9300
# Epoch 85: Train Loss=0.6540, Train Acc=0.9460, Test Loss=0.6560, Test Acc=0.9300
# Epoch 86: Train Loss=0.6514, Train Acc=0.9460, Test Loss=0.6536, Test Acc=0.9300
# Epoch 87: Train Loss=0.6487, Train Acc=0.9480, Test Loss=0.6509, Test Acc=0.9350
# Epoch 88: Train Loss=0.6457, Train Acc=0.9500, Test Loss=0.6481, Test Acc=0.9350
# Epoch 89: Train Loss=0.6426, Train Acc=0.9500, Test Loss=0.6451, Test Acc=0.9350
# Epoch 90: Train Loss=0.6392, Train Acc=0.9500, Test Loss=0.6418, Test Acc=0.9350
# Epoch 91: Train Loss=0.6356, Train Acc=0.9500, Test Loss=0.6384, Test Acc=0.9350
# Epoch 92: Train Loss=0.6318, Train Acc=0.9500, Test Loss=0.6347, Test Acc=0.9350
# Epoch 93: Train Loss=0.6277, Train Acc=0.9500, Test Loss=0.6307, Test Acc=0.9350
# Epoch 94: Train Loss=0.6233, Train Acc=0.9500, Test Loss=0.6265, Test Acc=0.9350
# Epoch 95: Train Loss=0.6186, Train Acc=0.9500, Test Loss=0.6219, Test Acc=0.9350
# Epoch 96: Train Loss=0.6136, Train Acc=0.9520, Test Loss=0.6171, Test Acc=0.9300
# Epoch 97: Train Loss=0.6084, Train Acc=0.9520, Test Loss=0.6120, Test Acc=0.9300
# Epoch 98: Train Loss=0.6028, Train Acc=0.9540, Test Loss=0.6066, Test Acc=0.9300
# Epoch 99: Train Loss=0.5968, Train Acc=0.9540, Test Loss=0.6008, Test Acc=0.9300
# Epoch 100: Train Loss=0.5906, Train Acc=0.9540, Test Loss=0.5948, Test Acc=0.9300
# Epoch 101: Train Loss=0.5840, Train Acc=0.9560, Test Loss=0.5884, Test Acc=0.9300
# Epoch 102: Train Loss=0.5771, Train Acc=0.9560, Test Loss=0.5817, Test Acc=0.9300
# Epoch 103: Train Loss=0.5698, Train Acc=0.9560, Test Loss=0.5747, Test Acc=0.9350
# Epoch 104: Train Loss=0.5623, Train Acc=0.9580, Test Loss=0.5674, Test Acc=0.9350
# Epoch 105: Train Loss=0.5544, Train Acc=0.9580, Test Loss=0.5598, Test Acc=0.9350
# Epoch 106: Train Loss=0.5463, Train Acc=0.9580, Test Loss=0.5520, Test Acc=0.9350
# Epoch 107: Train Loss=0.5380, Train Acc=0.9580, Test Loss=0.5439, Test Acc=0.9350
# Epoch 108: Train Loss=0.5295, Train Acc=0.9580, Test Loss=0.5357, Test Acc=0.9350
# Epoch 109: Train Loss=0.5208, Train Acc=0.9580, Test Loss=0.5273, Test Acc=0.9350
# Epoch 110: Train Loss=0.5121, Train Acc=0.9580, Test Loss=0.5189, Test Acc=0.9350
# Epoch 111: Train Loss=0.5033, Train Acc=0.9580, Test Loss=0.5105, Test Acc=0.9350
# Epoch 112: Train Loss=0.4945, Train Acc=0.9580, Test Loss=0.5021, Test Acc=0.9350
# Epoch 113: Train Loss=0.4858, Train Acc=0.9560, Test Loss=0.4937, Test Acc=0.9350
# Epoch 114: Train Loss=0.4772, Train Acc=0.9560, Test Loss=0.4855, Test Acc=0.9350
# Epoch 115: Train Loss=0.4688, Train Acc=0.9560, Test Loss=0.4774, Test Acc=0.9350
# Epoch 116: Train Loss=0.4606, Train Acc=0.9560, Test Loss=0.4695, Test Acc=0.9350
# Epoch 117: Train Loss=0.4525, Train Acc=0.9580, Test Loss=0.4618, Test Acc=0.9400
# Epoch 118: Train Loss=0.4447, Train Acc=0.9580, Test Loss=0.4543, Test Acc=0.9400
# Epoch 119: Train Loss=0.4370, Train Acc=0.9580, Test Loss=0.4470, Test Acc=0.9400
# Epoch 120: Train Loss=0.4296, Train Acc=0.9580, Test Loss=0.4398, Test Acc=0.9400
# Epoch 121: Train Loss=0.4223, Train Acc=0.9580, Test Loss=0.4328, Test Acc=0.9400
# Epoch 122: Train Loss=0.4153, Train Acc=0.9580, Test Loss=0.4261, Test Acc=0.9400
# Epoch 123: Train Loss=0.4086, Train Acc=0.9560, Test Loss=0.4197, Test Acc=0.9400
# Epoch 124: Train Loss=0.4020, Train Acc=0.9560, Test Loss=0.4135, Test Acc=0.9400
# Epoch 125: Train Loss=0.3956, Train Acc=0.9600, Test Loss=0.4073, Test Acc=0.9400
# Epoch 126: Train Loss=0.3894, Train Acc=0.9600, Test Loss=0.4015, Test Acc=0.9400
# Epoch 127: Train Loss=0.3835, Train Acc=0.9600, Test Loss=0.3959, Test Acc=0.9400
# Epoch 128: Train Loss=0.3779, Train Acc=0.9600, Test Loss=0.3906, Test Acc=0.9400
# Epoch 129: Train Loss=0.3725, Train Acc=0.9600, Test Loss=0.3855, Test Acc=0.9400
# Epoch 130: Train Loss=0.3673, Train Acc=0.9600, Test Loss=0.3806, Test Acc=0.9400
# Epoch 131: Train Loss=0.3623, Train Acc=0.9600, Test Loss=0.3759, Test Acc=0.9400
# Epoch 132: Train Loss=0.3574, Train Acc=0.9600, Test Loss=0.3713, Test Acc=0.9400
# Epoch 133: Train Loss=0.3526, Train Acc=0.9600, Test Loss=0.3668, Test Acc=0.9400
# Epoch 134: Train Loss=0.3481, Train Acc=0.9600, Test Loss=0.3625, Test Acc=0.9400
# Epoch 135: Train Loss=0.3437, Train Acc=0.9600, Test Loss=0.3584, Test Acc=0.9400
# Epoch 136: Train Loss=0.3394, Train Acc=0.9600, Test Loss=0.3545, Test Acc=0.9400
# Epoch 137: Train Loss=0.3353, Train Acc=0.9600, Test Loss=0.3506, Test Acc=0.9400
# Epoch 138: Train Loss=0.3313, Train Acc=0.9600, Test Loss=0.3470, Test Acc=0.9400
# Epoch 139: Train Loss=0.3274, Train Acc=0.9600, Test Loss=0.3434, Test Acc=0.9400
# Epoch 140: Train Loss=0.3237, Train Acc=0.9600, Test Loss=0.3400, Test Acc=0.9400
# Epoch 141: Train Loss=0.3201, Train Acc=0.9600, Test Loss=0.3366, Test Acc=0.9400
# Epoch 142: Train Loss=0.3166, Train Acc=0.9600, Test Loss=0.3334, Test Acc=0.9400
# Epoch 143: Train Loss=0.3132, Train Acc=0.9600, Test Loss=0.3303, Test Acc=0.9400
# Epoch 144: Train Loss=0.3099, Train Acc=0.9600, Test Loss=0.3273, Test Acc=0.9400
# Epoch 145: Train Loss=0.3067, Train Acc=0.9600, Test Loss=0.3243, Test Acc=0.9350
# Epoch 146: Train Loss=0.3036, Train Acc=0.9600, Test Loss=0.3214, Test Acc=0.9350
# Epoch 147: Train Loss=0.3006, Train Acc=0.9600, Test Loss=0.3186, Test Acc=0.9350
# Epoch 148: Train Loss=0.2976, Train Acc=0.9600, Test Loss=0.3159, Test Acc=0.9350
# Epoch 149: Train Loss=0.2947, Train Acc=0.9600, Test Loss=0.3133, Test Acc=0.9350
# Epoch 150: Train Loss=0.2920, Train Acc=0.9600, Test Loss=0.3108, Test Acc=0.9350
# Epoch 151: Train Loss=0.2893, Train Acc=0.9600, Test Loss=0.3083, Test Acc=0.9350
# Epoch 152: Train Loss=0.2867, Train Acc=0.9600, Test Loss=0.3059, Test Acc=0.9350
# Epoch 153: Train Loss=0.2842, Train Acc=0.9600, Test Loss=0.3037, Test Acc=0.9350
# Epoch 154: Train Loss=0.2817, Train Acc=0.9600, Test Loss=0.3014, Test Acc=0.9350
# Epoch 155: Train Loss=0.2793, Train Acc=0.9600, Test Loss=0.2992, Test Acc=0.9350
# Epoch 156: Train Loss=0.2770, Train Acc=0.9600, Test Loss=0.2971, Test Acc=0.9350
# Epoch 157: Train Loss=0.2747, Train Acc=0.9600, Test Loss=0.2951, Test Acc=0.9350
# Epoch 158: Train Loss=0.2725, Train Acc=0.9620, Test Loss=0.2931, Test Acc=0.9400
# Epoch 159: Train Loss=0.2704, Train Acc=0.9620, Test Loss=0.2911, Test Acc=0.9400
# Epoch 160: Train Loss=0.2683, Train Acc=0.9620, Test Loss=0.2892, Test Acc=0.9400
# Epoch 161: Train Loss=0.2662, Train Acc=0.9620, Test Loss=0.2874, Test Acc=0.9400
# Epoch 162: Train Loss=0.2642, Train Acc=0.9620, Test Loss=0.2856, Test Acc=0.9400
# Epoch 163: Train Loss=0.2623, Train Acc=0.9620, Test Loss=0.2839, Test Acc=0.9400
# Epoch 164: Train Loss=0.2604, Train Acc=0.9620, Test Loss=0.2822, Test Acc=0.9400
# Epoch 165: Train Loss=0.2585, Train Acc=0.9620, Test Loss=0.2805, Test Acc=0.9400
# Epoch 166: Train Loss=0.2567, Train Acc=0.9620, Test Loss=0.2789, Test Acc=0.9400
# Epoch 167: Train Loss=0.2549, Train Acc=0.9620, Test Loss=0.2773, Test Acc=0.9400
# Epoch 168: Train Loss=0.2532, Train Acc=0.9620, Test Loss=0.2758, Test Acc=0.9400
# Epoch 169: Train Loss=0.2515, Train Acc=0.9620, Test Loss=0.2743, Test Acc=0.9400
# Epoch 170: Train Loss=0.2499, Train Acc=0.9620, Test Loss=0.2728, Test Acc=0.9400
# Epoch 171: Train Loss=0.2483, Train Acc=0.9620, Test Loss=0.2714, Test Acc=0.9400
# Epoch 172: Train Loss=0.2467, Train Acc=0.9620, Test Loss=0.2700, Test Acc=0.9400
# Epoch 173: Train Loss=0.2452, Train Acc=0.9620, Test Loss=0.2687, Test Acc=0.9400
# Epoch 174: Train Loss=0.2437, Train Acc=0.9620, Test Loss=0.2674, Test Acc=0.9400
# Epoch 175: Train Loss=0.2422, Train Acc=0.9640, Test Loss=0.2661, Test Acc=0.9400
# Epoch 176: Train Loss=0.2408, Train Acc=0.9640, Test Loss=0.2649, Test Acc=0.9400
# Epoch 177: Train Loss=0.2394, Train Acc=0.9640, Test Loss=0.2636, Test Acc=0.9400
# Epoch 178: Train Loss=0.2380, Train Acc=0.9640, Test Loss=0.2625, Test Acc=0.9400
# Epoch 179: Train Loss=0.2367, Train Acc=0.9640, Test Loss=0.2613, Test Acc=0.9400
# Epoch 180: Train Loss=0.2354, Train Acc=0.9640, Test Loss=0.2602, Test Acc=0.9400
# Epoch 181: Train Loss=0.2341, Train Acc=0.9640, Test Loss=0.2591, Test Acc=0.9400
# Epoch 182: Train Loss=0.2329, Train Acc=0.9640, Test Loss=0.2580, Test Acc=0.9400
# Epoch 183: Train Loss=0.2317, Train Acc=0.9640, Test Loss=0.2570, Test Acc=0.9400
# Epoch 184: Train Loss=0.2305, Train Acc=0.9640, Test Loss=0.2559, Test Acc=0.9400
# Epoch 185: Train Loss=0.2293, Train Acc=0.9640, Test Loss=0.2549, Test Acc=0.9400
# Epoch 186: Train Loss=0.2282, Train Acc=0.9640, Test Loss=0.2540, Test Acc=0.9400
# Epoch 187: Train Loss=0.2270, Train Acc=0.9640, Test Loss=0.2530, Test Acc=0.9400
# Epoch 188: Train Loss=0.2259, Train Acc=0.9640, Test Loss=0.2521, Test Acc=0.9400
# Epoch 189: Train Loss=0.2249, Train Acc=0.9640, Test Loss=0.2512, Test Acc=0.9400
# Epoch 190: Train Loss=0.2238, Train Acc=0.9640, Test Loss=0.2503, Test Acc=0.9400
# Epoch 191: Train Loss=0.2228, Train Acc=0.9640, Test Loss=0.2494, Test Acc=0.9400
# Epoch 192: Train Loss=0.2218, Train Acc=0.9640, Test Loss=0.2485, Test Acc=0.9400
# Epoch 193: Train Loss=0.2208, Train Acc=0.9640, Test Loss=0.2477, Test Acc=0.9400
# Epoch 194: Train Loss=0.2198, Train Acc=0.9660, Test Loss=0.2469, Test Acc=0.9400
# Epoch 195: Train Loss=0.2189, Train Acc=0.9660, Test Loss=0.2461, Test Acc=0.9400
# Epoch 196: Train Loss=0.2180, Train Acc=0.9660, Test Loss=0.2453, Test Acc=0.9400
# Epoch 197: Train Loss=0.2171, Train Acc=0.9660, Test Loss=0.2445, Test Acc=0.9400
# Epoch 198: Train Loss=0.2162, Train Acc=0.9660, Test Loss=0.2438, Test Acc=0.9400
# Epoch 199: Train Loss=0.2153, Train Acc=0.9660, Test Loss=0.2431, Test Acc=0.9400
# Epoch 200: Train Loss=0.2144, Train Acc=0.9660, Test Loss=0.2424, Test Acc=0.9400
# Epoch 201: Train Loss=0.2136, Train Acc=0.9660, Test Loss=0.2417, Test Acc=0.9400
# Epoch 202: Train Loss=0.2128, Train Acc=0.9660, Test Loss=0.2410, Test Acc=0.9400
# Epoch 203: Train Loss=0.2120, Train Acc=0.9660, Test Loss=0.2403, Test Acc=0.9400
# Epoch 204: Train Loss=0.2112, Train Acc=0.9660, Test Loss=0.2396, Test Acc=0.9400
# Epoch 205: Train Loss=0.2104, Train Acc=0.9660, Test Loss=0.2390, Test Acc=0.9400
# Epoch 206: Train Loss=0.2096, Train Acc=0.9660, Test Loss=0.2384, Test Acc=0.9400
# Epoch 207: Train Loss=0.2089, Train Acc=0.9660, Test Loss=0.2378, Test Acc=0.9400
# Epoch 208: Train Loss=0.2081, Train Acc=0.9660, Test Loss=0.2372, Test Acc=0.9400
# Epoch 209: Train Loss=0.2074, Train Acc=0.9660, Test Loss=0.2366, Test Acc=0.9400
# Epoch 210: Train Loss=0.2067, Train Acc=0.9660, Test Loss=0.2360, Test Acc=0.9400
# Epoch 211: Train Loss=0.2060, Train Acc=0.9640, Test Loss=0.2354, Test Acc=0.9400
# Epoch 212: Train Loss=0.2053, Train Acc=0.9640, Test Loss=0.2349, Test Acc=0.9400
# Epoch 213: Train Loss=0.2046, Train Acc=0.9640, Test Loss=0.2343, Test Acc=0.9400
# Epoch 214: Train Loss=0.2040, Train Acc=0.9640, Test Loss=0.2338, Test Acc=0.9400
# Epoch 215: Train Loss=0.2033, Train Acc=0.9640, Test Loss=0.2333, Test Acc=0.9400
# Epoch 216: Train Loss=0.2027, Train Acc=0.9640, Test Loss=0.2328, Test Acc=0.9400
# Epoch 217: Train Loss=0.2021, Train Acc=0.9640, Test Loss=0.2323, Test Acc=0.9400
# Epoch 218: Train Loss=0.2015, Train Acc=0.9640, Test Loss=0.2318, Test Acc=0.9400
# Epoch 219: Train Loss=0.2009, Train Acc=0.9640, Test Loss=0.2313, Test Acc=0.9400
# Epoch 220: Train Loss=0.2003, Train Acc=0.9640, Test Loss=0.2308, Test Acc=0.9400
# Epoch 221: Train Loss=0.1997, Train Acc=0.9640, Test Loss=0.2303, Test Acc=0.9400
# Epoch 222: Train Loss=0.1991, Train Acc=0.9640, Test Loss=0.2299, Test Acc=0.9400
# Epoch 223: Train Loss=0.1985, Train Acc=0.9640, Test Loss=0.2294, Test Acc=0.9400
# Epoch 224: Train Loss=0.1980, Train Acc=0.9640, Test Loss=0.2290, Test Acc=0.9400
# Epoch 225: Train Loss=0.1974, Train Acc=0.9640, Test Loss=0.2286, Test Acc=0.9400
# Epoch 226: Train Loss=0.1969, Train Acc=0.9640, Test Loss=0.2282, Test Acc=0.9400
# Epoch 227: Train Loss=0.1964, Train Acc=0.9640, Test Loss=0.2277, Test Acc=0.9400
# Epoch 228: Train Loss=0.1959, Train Acc=0.9640, Test Loss=0.2273, Test Acc=0.9400
# Epoch 229: Train Loss=0.1954, Train Acc=0.9640, Test Loss=0.2269, Test Acc=0.9400
# Epoch 230: Train Loss=0.1949, Train Acc=0.9640, Test Loss=0.2265, Test Acc=0.9400
# Epoch 231: Train Loss=0.1944, Train Acc=0.9640, Test Loss=0.2262, Test Acc=0.9400
# Epoch 232: Train Loss=0.1939, Train Acc=0.9640, Test Loss=0.2258, Test Acc=0.9400
# Epoch 233: Train Loss=0.1934, Train Acc=0.9640, Test Loss=0.2254, Test Acc=0.9400
# Epoch 234: Train Loss=0.1929, Train Acc=0.9640, Test Loss=0.2251, Test Acc=0.9400
# Epoch 235: Train Loss=0.1925, Train Acc=0.9640, Test Loss=0.2247, Test Acc=0.9400
# Epoch 236: Train Loss=0.1920, Train Acc=0.9640, Test Loss=0.2243, Test Acc=0.9400
# Epoch 237: Train Loss=0.1916, Train Acc=0.9640, Test Loss=0.2240, Test Acc=0.9400
# Epoch 238: Train Loss=0.1911, Train Acc=0.9640, Test Loss=0.2237, Test Acc=0.9400
# Epoch 239: Train Loss=0.1907, Train Acc=0.9640, Test Loss=0.2233, Test Acc=0.9400
# Epoch 240: Train Loss=0.1903, Train Acc=0.9640, Test Loss=0.2230, Test Acc=0.9400
# Epoch 241: Train Loss=0.1898, Train Acc=0.9640, Test Loss=0.2227, Test Acc=0.9400
# Epoch 242: Train Loss=0.1894, Train Acc=0.9640, Test Loss=0.2224, Test Acc=0.9400
# Epoch 243: Train Loss=0.1890, Train Acc=0.9640, Test Loss=0.2221, Test Acc=0.9400
# Epoch 244: Train Loss=0.1886, Train Acc=0.9640, Test Loss=0.2218, Test Acc=0.9400
# Epoch 245: Train Loss=0.1882, Train Acc=0.9640, Test Loss=0.2215, Test Acc=0.9400
# Epoch 246: Train Loss=0.1878, Train Acc=0.9640, Test Loss=0.2212, Test Acc=0.9400
# Epoch 247: Train Loss=0.1874, Train Acc=0.9640, Test Loss=0.2209, Test Acc=0.9400
# Epoch 248: Train Loss=0.1871, Train Acc=0.9640, Test Loss=0.2206, Test Acc=0.9400
# Epoch 249: Train Loss=0.1867, Train Acc=0.9640, Test Loss=0.2203, Test Acc=0.9400
# Epoch 250: Train Loss=0.1863, Train Acc=0.9640, Test Loss=0.2200, Test Acc=0.9400
# Epoch 251: Train Loss=0.1860, Train Acc=0.9640, Test Loss=0.2198, Test Acc=0.9400
# Epoch 252: Train Loss=0.1856, Train Acc=0.9640, Test Loss=0.2195, Test Acc=0.9400
# Epoch 253: Train Loss=0.1853, Train Acc=0.9640, Test Loss=0.2192, Test Acc=0.9400
# Epoch 254: Train Loss=0.1849, Train Acc=0.9640, Test Loss=0.2190, Test Acc=0.9400
# Epoch 255: Train Loss=0.1846, Train Acc=0.9640, Test Loss=0.2187, Test Acc=0.9400
# Epoch 256: Train Loss=0.1842, Train Acc=0.9640, Test Loss=0.2185, Test Acc=0.9400
# Epoch 257: Train Loss=0.1839, Train Acc=0.9640, Test Loss=0.2182, Test Acc=0.9400
# Epoch 258: Train Loss=0.1836, Train Acc=0.9660, Test Loss=0.2180, Test Acc=0.9400
# Epoch 259: Train Loss=0.1833, Train Acc=0.9660, Test Loss=0.2178, Test Acc=0.9400
# Epoch 260: Train Loss=0.1829, Train Acc=0.9660, Test Loss=0.2175, Test Acc=0.9400
# Epoch 261: Train Loss=0.1826, Train Acc=0.9660, Test Loss=0.2173, Test Acc=0.9400
# Epoch 262: Train Loss=0.1823, Train Acc=0.9660, Test Loss=0.2171, Test Acc=0.9400
# Epoch 263: Train Loss=0.1820, Train Acc=0.9660, Test Loss=0.2169, Test Acc=0.9400
# Epoch 264: Train Loss=0.1817, Train Acc=0.9660, Test Loss=0.2166, Test Acc=0.9400
# Epoch 265: Train Loss=0.1814, Train Acc=0.9660, Test Loss=0.2164, Test Acc=0.9400
# Epoch 266: Train Loss=0.1811, Train Acc=0.9660, Test Loss=0.2162, Test Acc=0.9400
# Epoch 267: Train Loss=0.1808, Train Acc=0.9660, Test Loss=0.2160, Test Acc=0.9400
# Epoch 268: Train Loss=0.1805, Train Acc=0.9660, Test Loss=0.2158, Test Acc=0.9400
# Epoch 269: Train Loss=0.1803, Train Acc=0.9660, Test Loss=0.2156, Test Acc=0.9400
# Epoch 270: Train Loss=0.1800, Train Acc=0.9660, Test Loss=0.2154, Test Acc=0.9400
# Epoch 271: Train Loss=0.1797, Train Acc=0.9660, Test Loss=0.2152, Test Acc=0.9400
# Epoch 272: Train Loss=0.1794, Train Acc=0.9640, Test Loss=0.2150, Test Acc=0.9400
# Epoch 273: Train Loss=0.1792, Train Acc=0.9640, Test Loss=0.2148, Test Acc=0.9400
# Epoch 274: Train Loss=0.1789, Train Acc=0.9640, Test Loss=0.2146, Test Acc=0.9400
# Epoch 275: Train Loss=0.1787, Train Acc=0.9640, Test Loss=0.2144, Test Acc=0.9400
# Epoch 276: Train Loss=0.1784, Train Acc=0.9640, Test Loss=0.2142, Test Acc=0.9400
# Epoch 277: Train Loss=0.1781, Train Acc=0.9640, Test Loss=0.2141, Test Acc=0.9400
# Epoch 278: Train Loss=0.1779, Train Acc=0.9640, Test Loss=0.2139, Test Acc=0.9400
# Epoch 279: Train Loss=0.1776, Train Acc=0.9640, Test Loss=0.2137, Test Acc=0.9400
# Epoch 280: Train Loss=0.1774, Train Acc=0.9640, Test Loss=0.2135, Test Acc=0.9400
# Epoch 281: Train Loss=0.1772, Train Acc=0.9640, Test Loss=0.2134, Test Acc=0.9400
# Epoch 282: Train Loss=0.1769, Train Acc=0.9660, Test Loss=0.2132, Test Acc=0.9400
# Epoch 283: Train Loss=0.1767, Train Acc=0.9660, Test Loss=0.2130, Test Acc=0.9400
# Epoch 284: Train Loss=0.1765, Train Acc=0.9660, Test Loss=0.2129, Test Acc=0.9400
# Epoch 285: Train Loss=0.1762, Train Acc=0.9660, Test Loss=0.2127, Test Acc=0.9400
# Epoch 286: Train Loss=0.1760, Train Acc=0.9660, Test Loss=0.2126, Test Acc=0.9400
# Epoch 287: Train Loss=0.1758, Train Acc=0.9660, Test Loss=0.2124, Test Acc=0.9400
# Epoch 288: Train Loss=0.1756, Train Acc=0.9660, Test Loss=0.2123, Test Acc=0.9400
# Epoch 289: Train Loss=0.1753, Train Acc=0.9660, Test Loss=0.2121, Test Acc=0.9400
# Epoch 290: Train Loss=0.1751, Train Acc=0.9660, Test Loss=0.2120, Test Acc=0.9400
# Epoch 291: Train Loss=0.1749, Train Acc=0.9660, Test Loss=0.2118, Test Acc=0.9400
# Epoch 292: Train Loss=0.1747, Train Acc=0.9660, Test Loss=0.2117, Test Acc=0.9400
# Epoch 293: Train Loss=0.1745, Train Acc=0.9660, Test Loss=0.2115, Test Acc=0.9400
# Epoch 294: Train Loss=0.1743, Train Acc=0.9660, Test Loss=0.2114, Test Acc=0.9400
# Epoch 295: Train Loss=0.1741, Train Acc=0.9660, Test Loss=0.2113, Test Acc=0.9400
# Epoch 296: Train Loss=0.1739, Train Acc=0.9660, Test Loss=0.2111, Test Acc=0.9400
# Epoch 297: Train Loss=0.1737, Train Acc=0.9660, Test Loss=0.2110, Test Acc=0.9400
# Epoch 298: Train Loss=0.1735, Train Acc=0.9660, Test Loss=0.2108, Test Acc=0.9400
# Epoch 299: Train Loss=0.1733, Train Acc=0.9660, Test Loss=0.2107, Test Acc=0.9350
# Epoch 300: Train Loss=0.1731, Train Acc=0.9660, Test Loss=0.2106, Test Acc=0.9350

# %%
# plot training and testing losses
plt.plot(np.arange(epochs), torch.tensor(train_losses).detach().numpy(), label="Train")
plt.plot(np.arange(epochs), torch.tensor(test_losses).detach().numpy(), label="Test")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('Train and Test Loss - Implemetation from scratch')
plt.legend()
plt.savefig('nn_scratch_loss2.png')
plt.show()

# plot training and testing accuracies
plt.plot(np.arange(epochs), np.array(train_accs), label="Train")
plt.plot(np.arange(epochs), np.array(test_accs), label="Test")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title('Train and Test Accuracy  - Implemetation from scratch')
plt.legend()
plt.savefig('nn_scratch_acc2.png')
plt.show()
