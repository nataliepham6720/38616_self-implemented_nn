# %% [markdown]
# # 38616 - HW1: Implement a Neural Network with Pytorch
#
# Natalie Pham

# %%
import numpy as np
from matplotlib import pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from typing import Optional, List, Tuple, Dict


if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
class SingleLayerMLP(nn.Module):
    """constructing a single layer neural network with Pytorch"""
    def __init__(self, indim, outdim, hidden_layer=100):
        super(SingleLayerMLP, self).__init__()
        self.hidden_layer = nn.Linear(indim, hidden_layer)
        self.output = nn.Linear(hidden_layer, outdim)
        self.activation = nn.ReLU()
        # raise NotImplementedError()


    def forward(self, x):
        """
        x shape (batch_size, input_dim)
        """
        x = x.to(self.hidden_layer.weight.dtype)
        hidden = self.hidden_layer(x)
        activate = self.activation(hidden)
        output = self.output(activate)
        return output



class DS(Dataset):
    def __init__(self, X: np.ndarray, Y: np.ndarray):
        self.length = len(X)
        self.X = X
        self.Y = Y

    def __getitem__(self, idx):
        x = self.X[idx, :]
        y = self.Y[idx]
        return (x, y)

    def __len__(self):
        return self.length


def validate(model, loader, loss_fnc, optimizer):
    """takes in a dataloader, then returns the model loss and accuracy on this loader"""
    
    with torch.no_grad():
        total_loss = 0
        total_correct = 0
        total_samples = 0
        
        model.eval()
        for x, y in loader:
            x, y = x.to(device), y.to(device).long()
            outputs = model(x)
            loss = loss_fnc(outputs, y)
            total_loss += loss.item() * x.shape[0]
            predictions = outputs.argmax(dim=1)
            total_correct += (predictions == y).sum().item()
            total_samples += x.shape[0]
            
        # Calculate the average loss and accuracy
        average_loss = total_loss / total_samples
        average_accuracy = total_correct / total_samples

        return average_loss, average_accuracy


def train(model, train_loader, criterion, optimizer):
    total_loss = 0
    total_correct = 0
    total_samples = 0
    
    model.train()
    for x, y in train_loader:
        x, y = x.to(device), y.to(device).long()
        optimizer.zero_grad()
        outputs = model(x)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * x.shape[0]
        predictions = outputs.argmax(dim=1)
        total_correct += (predictions == y).sum().item()
        total_samples += x.shape[0]

    # Calculate the average loss and accuracy
    average_loss = total_loss / total_samples
    average_accuracy = total_correct / total_samples

    return average_loss, average_accuracy

# %%
if __name__ == "__main__":
    """The dataset loaders were provided for you.
    You need to implement your own training process.
    You need plot the loss and accuracies during the training process and test process. 
    """


    indim = 10
    outdim = 2
    hidden_dim = 100
    lr = 0.01
    batch_size = 64
    epochs = 200

    #dataset
    Xtrain = np.loadtxt("data/XTrain.txt", delimiter="\t")
    Ytrain = np.loadtxt("data/yTrain.txt", delimiter="\t").astype(int)
    m1, n1 = Xtrain.shape
    print(m1, n1)
    train_ds = DS(Xtrain, Ytrain)
    train_loader = DataLoader(train_ds, batch_size=batch_size)

    Xtest = np.loadtxt("data/XTest.txt", delimiter="\t")
    Ytest = np.loadtxt("data/yTest.txt", delimiter="\t").astype(int)
    m2, n2 = Xtest.shape
    print(m1, n2)
    test_ds = DS(Xtest, Ytest)
    test_loader = DataLoader(test_ds, batch_size=batch_size)

    #construct the model
    model = SingleLayerMLP(indim, outdim, hidden_dim).to(device)

    # Define the loss function
    loss_fnc = nn.CrossEntropyLoss()

    # Define the optimizer
    optimizer = optim.SGD(model.parameters(), lr=lr)
    
    #construct the training process
    train_losses, train_accs, test_losses, test_accs = [], [], [], []
    for epoch in range(epochs):
        # Train the model
        train_loss, train_acc = train(model, train_loader, loss_fnc, optimizer)
        train_losses.append(train_loss)
        train_accs.append(train_acc)

        # Evaluate the model on the test set
        test_loss, test_acc = validate(model, test_loader, loss_fnc, optimizer)
        test_losses.append(test_loss)
        test_accs.append(test_acc)

        # Print the results for this epoch
        print(f"Epoch {epoch+1}: Train Loss={train_loss:.4f}, Train Acc={train_acc:.4f}, Test Loss={test_loss:.4f}, Test Acc={test_acc:.4f}")
# Out:
# 500 10
# 500 10
# Epoch 1: Train Loss=0.7081, Train Acc=0.5500, Test Loss=0.6853, Test Acc=0.6100
# Epoch 2: Train Loss=0.6354, Train Acc=0.7460, Test Loss=0.6115, Test Acc=0.7750
# Epoch 3: Train Loss=0.5791, Train Acc=0.8700, Test Loss=0.5549, Test Acc=0.8500
# Epoch 4: Train Loss=0.5339, Train Acc=0.9060, Test Loss=0.5102, Test Acc=0.8850
# Epoch 5: Train Loss=0.4969, Train Acc=0.9240, Test Loss=0.4738, Test Acc=0.8950
# Epoch 6: Train Loss=0.4658, Train Acc=0.9340, Test Loss=0.4436, Test Acc=0.8950
# Epoch 7: Train Loss=0.4394, Train Acc=0.9420, Test Loss=0.4182, Test Acc=0.9000
# Epoch 8: Train Loss=0.4167, Train Acc=0.9440, Test Loss=0.3966, Test Acc=0.9100
# Epoch 9: Train Loss=0.3969, Train Acc=0.9460, Test Loss=0.3779, Test Acc=0.9100
# Epoch 10: Train Loss=0.3795, Train Acc=0.9460, Test Loss=0.3616, Test Acc=0.9150
# Epoch 11: Train Loss=0.3641, Train Acc=0.9460, Test Loss=0.3473, Test Acc=0.9250
# Epoch 12: Train Loss=0.3504, Train Acc=0.9460, Test Loss=0.3347, Test Acc=0.9250
# Epoch 13: Train Loss=0.3381, Train Acc=0.9460, Test Loss=0.3235, Test Acc=0.9200
# Epoch 14: Train Loss=0.3270, Train Acc=0.9480, Test Loss=0.3135, Test Acc=0.9250
# Epoch 15: Train Loss=0.3169, Train Acc=0.9480, Test Loss=0.3045, Test Acc=0.9250
# Epoch 16: Train Loss=0.3077, Train Acc=0.9460, Test Loss=0.2963, Test Acc=0.9250
# Epoch 17: Train Loss=0.2993, Train Acc=0.9460, Test Loss=0.2889, Test Acc=0.9250
# Epoch 18: Train Loss=0.2916, Train Acc=0.9460, Test Loss=0.2822, Test Acc=0.9250
# Epoch 19: Train Loss=0.2845, Train Acc=0.9480, Test Loss=0.2760, Test Acc=0.9250
# Epoch 20: Train Loss=0.2779, Train Acc=0.9480, Test Loss=0.2703, Test Acc=0.9250
# Epoch 21: Train Loss=0.2718, Train Acc=0.9480, Test Loss=0.2651, Test Acc=0.9250
# Epoch 22: Train Loss=0.2661, Train Acc=0.9480, Test Loss=0.2603, Test Acc=0.9300
# Epoch 23: Train Loss=0.2608, Train Acc=0.9480, Test Loss=0.2558, Test Acc=0.9300
# Epoch 24: Train Loss=0.2559, Train Acc=0.9500, Test Loss=0.2517, Test Acc=0.9350
# Epoch 25: Train Loss=0.2512, Train Acc=0.9500, Test Loss=0.2478, Test Acc=0.9350
# Epoch 26: Train Loss=0.2468, Train Acc=0.9500, Test Loss=0.2442, Test Acc=0.9350
# Epoch 27: Train Loss=0.2427, Train Acc=0.9520, Test Loss=0.2408, Test Acc=0.9350
# Epoch 28: Train Loss=0.2389, Train Acc=0.9520, Test Loss=0.2377, Test Acc=0.9400
# Epoch 29: Train Loss=0.2352, Train Acc=0.9520, Test Loss=0.2347, Test Acc=0.9400
# Epoch 30: Train Loss=0.2317, Train Acc=0.9520, Test Loss=0.2319, Test Acc=0.9450
# Epoch 31: Train Loss=0.2285, Train Acc=0.9520, Test Loss=0.2293, Test Acc=0.9450
# Epoch 32: Train Loss=0.2254, Train Acc=0.9540, Test Loss=0.2268, Test Acc=0.9450
# Epoch 33: Train Loss=0.2224, Train Acc=0.9540, Test Loss=0.2245, Test Acc=0.9450
# Epoch 34: Train Loss=0.2196, Train Acc=0.9540, Test Loss=0.2223, Test Acc=0.9450
# Epoch 35: Train Loss=0.2169, Train Acc=0.9560, Test Loss=0.2202, Test Acc=0.9450
# Epoch 36: Train Loss=0.2143, Train Acc=0.9560, Test Loss=0.2182, Test Acc=0.9450
# Epoch 37: Train Loss=0.2119, Train Acc=0.9560, Test Loss=0.2163, Test Acc=0.9450
# Epoch 38: Train Loss=0.2096, Train Acc=0.9560, Test Loss=0.2145, Test Acc=0.9450
# Epoch 39: Train Loss=0.2073, Train Acc=0.9580, Test Loss=0.2128, Test Acc=0.9450
# Epoch 40: Train Loss=0.2052, Train Acc=0.9580, Test Loss=0.2111, Test Acc=0.9450
# Epoch 41: Train Loss=0.2031, Train Acc=0.9580, Test Loss=0.2096, Test Acc=0.9450
# Epoch 42: Train Loss=0.2012, Train Acc=0.9580, Test Loss=0.2081, Test Acc=0.9450
# Epoch 43: Train Loss=0.1993, Train Acc=0.9580, Test Loss=0.2067, Test Acc=0.9450
# Epoch 44: Train Loss=0.1975, Train Acc=0.9580, Test Loss=0.2053, Test Acc=0.9450
# Epoch 45: Train Loss=0.1957, Train Acc=0.9580, Test Loss=0.2040, Test Acc=0.9450
# Epoch 46: Train Loss=0.1940, Train Acc=0.9580, Test Loss=0.2028, Test Acc=0.9450
# Epoch 47: Train Loss=0.1924, Train Acc=0.9580, Test Loss=0.2016, Test Acc=0.9450
# Epoch 48: Train Loss=0.1908, Train Acc=0.9580, Test Loss=0.2004, Test Acc=0.9450
# Epoch 49: Train Loss=0.1893, Train Acc=0.9580, Test Loss=0.1993, Test Acc=0.9450
# Epoch 50: Train Loss=0.1879, Train Acc=0.9580, Test Loss=0.1983, Test Acc=0.9450
# Epoch 51: Train Loss=0.1865, Train Acc=0.9580, Test Loss=0.1972, Test Acc=0.9450
# Epoch 52: Train Loss=0.1851, Train Acc=0.9580, Test Loss=0.1963, Test Acc=0.9450
# Epoch 53: Train Loss=0.1838, Train Acc=0.9580, Test Loss=0.1953, Test Acc=0.9450
# Epoch 54: Train Loss=0.1825, Train Acc=0.9580, Test Loss=0.1944, Test Acc=0.9450
# Epoch 55: Train Loss=0.1813, Train Acc=0.9600, Test Loss=0.1935, Test Acc=0.9450
# Epoch 56: Train Loss=0.1801, Train Acc=0.9600, Test Loss=0.1927, Test Acc=0.9450
# Epoch 57: Train Loss=0.1790, Train Acc=0.9600, Test Loss=0.1919, Test Acc=0.9450
# Epoch 58: Train Loss=0.1778, Train Acc=0.9600, Test Loss=0.1911, Test Acc=0.9450
# Epoch 59: Train Loss=0.1767, Train Acc=0.9600, Test Loss=0.1903, Test Acc=0.9400
# Epoch 60: Train Loss=0.1757, Train Acc=0.9600, Test Loss=0.1896, Test Acc=0.9400
# Epoch 61: Train Loss=0.1747, Train Acc=0.9600, Test Loss=0.1889, Test Acc=0.9400
# Epoch 62: Train Loss=0.1737, Train Acc=0.9600, Test Loss=0.1882, Test Acc=0.9400
# Epoch 63: Train Loss=0.1727, Train Acc=0.9600, Test Loss=0.1875, Test Acc=0.9400
# Epoch 64: Train Loss=0.1718, Train Acc=0.9600, Test Loss=0.1869, Test Acc=0.9400
# Epoch 65: Train Loss=0.1709, Train Acc=0.9600, Test Loss=0.1863, Test Acc=0.9400
# Epoch 66: Train Loss=0.1700, Train Acc=0.9600, Test Loss=0.1857, Test Acc=0.9400
# Epoch 67: Train Loss=0.1691, Train Acc=0.9600, Test Loss=0.1851, Test Acc=0.9400
# Epoch 68: Train Loss=0.1683, Train Acc=0.9600, Test Loss=0.1845, Test Acc=0.9400
# Epoch 69: Train Loss=0.1675, Train Acc=0.9600, Test Loss=0.1840, Test Acc=0.9400
# Epoch 70: Train Loss=0.1667, Train Acc=0.9600, Test Loss=0.1834, Test Acc=0.9400
# Epoch 71: Train Loss=0.1659, Train Acc=0.9600, Test Loss=0.1829, Test Acc=0.9400
# Epoch 72: Train Loss=0.1651, Train Acc=0.9600, Test Loss=0.1824, Test Acc=0.9400
# Epoch 73: Train Loss=0.1644, Train Acc=0.9600, Test Loss=0.1819, Test Acc=0.9400
# Epoch 74: Train Loss=0.1637, Train Acc=0.9600, Test Loss=0.1815, Test Acc=0.9400
# Epoch 75: Train Loss=0.1630, Train Acc=0.9600, Test Loss=0.1810, Test Acc=0.9400
# Epoch 76: Train Loss=0.1623, Train Acc=0.9600, Test Loss=0.1806, Test Acc=0.9400
# Epoch 77: Train Loss=0.1616, Train Acc=0.9600, Test Loss=0.1801, Test Acc=0.9400
# Epoch 78: Train Loss=0.1610, Train Acc=0.9600, Test Loss=0.1797, Test Acc=0.9400
# Epoch 79: Train Loss=0.1603, Train Acc=0.9600, Test Loss=0.1793, Test Acc=0.9400
# Epoch 80: Train Loss=0.1597, Train Acc=0.9600, Test Loss=0.1789, Test Acc=0.9400
# Epoch 81: Train Loss=0.1591, Train Acc=0.9600, Test Loss=0.1785, Test Acc=0.9400
# Epoch 82: Train Loss=0.1585, Train Acc=0.9600, Test Loss=0.1781, Test Acc=0.9400
# Epoch 83: Train Loss=0.1579, Train Acc=0.9600, Test Loss=0.1778, Test Acc=0.9400
# Epoch 84: Train Loss=0.1574, Train Acc=0.9600, Test Loss=0.1774, Test Acc=0.9400
# Epoch 85: Train Loss=0.1568, Train Acc=0.9600, Test Loss=0.1771, Test Acc=0.9400
# Epoch 86: Train Loss=0.1563, Train Acc=0.9600, Test Loss=0.1767, Test Acc=0.9400
# Epoch 87: Train Loss=0.1558, Train Acc=0.9600, Test Loss=0.1764, Test Acc=0.9400
# Epoch 88: Train Loss=0.1552, Train Acc=0.9620, Test Loss=0.1761, Test Acc=0.9400
# Epoch 89: Train Loss=0.1547, Train Acc=0.9620, Test Loss=0.1758, Test Acc=0.9400
# Epoch 90: Train Loss=0.1542, Train Acc=0.9640, Test Loss=0.1755, Test Acc=0.9400
# Epoch 91: Train Loss=0.1537, Train Acc=0.9640, Test Loss=0.1752, Test Acc=0.9400
# Epoch 92: Train Loss=0.1533, Train Acc=0.9640, Test Loss=0.1749, Test Acc=0.9400
# Epoch 93: Train Loss=0.1528, Train Acc=0.9660, Test Loss=0.1746, Test Acc=0.9400
# Epoch 94: Train Loss=0.1523, Train Acc=0.9660, Test Loss=0.1743, Test Acc=0.9400
# Epoch 95: Train Loss=0.1519, Train Acc=0.9660, Test Loss=0.1741, Test Acc=0.9400
# Epoch 96: Train Loss=0.1514, Train Acc=0.9660, Test Loss=0.1738, Test Acc=0.9400
# Epoch 97: Train Loss=0.1510, Train Acc=0.9660, Test Loss=0.1736, Test Acc=0.9400
# Epoch 98: Train Loss=0.1506, Train Acc=0.9660, Test Loss=0.1733, Test Acc=0.9400
# Epoch 99: Train Loss=0.1502, Train Acc=0.9660, Test Loss=0.1731, Test Acc=0.9400
# Epoch 100: Train Loss=0.1497, Train Acc=0.9660, Test Loss=0.1728, Test Acc=0.9400
# Epoch 101: Train Loss=0.1493, Train Acc=0.9660, Test Loss=0.1726, Test Acc=0.9400
# Epoch 102: Train Loss=0.1489, Train Acc=0.9680, Test Loss=0.1724, Test Acc=0.9400
# Epoch 103: Train Loss=0.1485, Train Acc=0.9680, Test Loss=0.1722, Test Acc=0.9400
# Epoch 104: Train Loss=0.1482, Train Acc=0.9680, Test Loss=0.1719, Test Acc=0.9400
# Epoch 105: Train Loss=0.1478, Train Acc=0.9680, Test Loss=0.1717, Test Acc=0.9400
# Epoch 106: Train Loss=0.1474, Train Acc=0.9680, Test Loss=0.1715, Test Acc=0.9400
# Epoch 107: Train Loss=0.1470, Train Acc=0.9680, Test Loss=0.1713, Test Acc=0.9400
# Epoch 108: Train Loss=0.1467, Train Acc=0.9680, Test Loss=0.1711, Test Acc=0.9400
# Epoch 109: Train Loss=0.1463, Train Acc=0.9680, Test Loss=0.1709, Test Acc=0.9400
# Epoch 110: Train Loss=0.1460, Train Acc=0.9680, Test Loss=0.1707, Test Acc=0.9400
# Epoch 111: Train Loss=0.1457, Train Acc=0.9680, Test Loss=0.1706, Test Acc=0.9400
# Epoch 112: Train Loss=0.1453, Train Acc=0.9680, Test Loss=0.1704, Test Acc=0.9400
# Epoch 113: Train Loss=0.1450, Train Acc=0.9680, Test Loss=0.1702, Test Acc=0.9400
# Epoch 114: Train Loss=0.1447, Train Acc=0.9680, Test Loss=0.1700, Test Acc=0.9400
# Epoch 115: Train Loss=0.1443, Train Acc=0.9680, Test Loss=0.1699, Test Acc=0.9400
# Epoch 116: Train Loss=0.1440, Train Acc=0.9680, Test Loss=0.1697, Test Acc=0.9400
# Epoch 117: Train Loss=0.1437, Train Acc=0.9680, Test Loss=0.1695, Test Acc=0.9400
# Epoch 118: Train Loss=0.1434, Train Acc=0.9680, Test Loss=0.1694, Test Acc=0.9400
# Epoch 119: Train Loss=0.1431, Train Acc=0.9680, Test Loss=0.1692, Test Acc=0.9400
# Epoch 120: Train Loss=0.1428, Train Acc=0.9680, Test Loss=0.1691, Test Acc=0.9400
# Epoch 121: Train Loss=0.1425, Train Acc=0.9680, Test Loss=0.1689, Test Acc=0.9400
# Epoch 122: Train Loss=0.1422, Train Acc=0.9680, Test Loss=0.1688, Test Acc=0.9400
# Epoch 123: Train Loss=0.1419, Train Acc=0.9680, Test Loss=0.1686, Test Acc=0.9400
# Epoch 124: Train Loss=0.1417, Train Acc=0.9680, Test Loss=0.1685, Test Acc=0.9400
# Epoch 125: Train Loss=0.1414, Train Acc=0.9680, Test Loss=0.1684, Test Acc=0.9400
# Epoch 126: Train Loss=0.1411, Train Acc=0.9680, Test Loss=0.1682, Test Acc=0.9400
# Epoch 127: Train Loss=0.1408, Train Acc=0.9680, Test Loss=0.1681, Test Acc=0.9400
# Epoch 128: Train Loss=0.1406, Train Acc=0.9680, Test Loss=0.1680, Test Acc=0.9400
# Epoch 129: Train Loss=0.1403, Train Acc=0.9680, Test Loss=0.1678, Test Acc=0.9400
# Epoch 130: Train Loss=0.1401, Train Acc=0.9680, Test Loss=0.1677, Test Acc=0.9400
# Epoch 131: Train Loss=0.1398, Train Acc=0.9680, Test Loss=0.1676, Test Acc=0.9400
# Epoch 132: Train Loss=0.1395, Train Acc=0.9680, Test Loss=0.1675, Test Acc=0.9400
# Epoch 133: Train Loss=0.1393, Train Acc=0.9680, Test Loss=0.1674, Test Acc=0.9400
# Epoch 134: Train Loss=0.1391, Train Acc=0.9680, Test Loss=0.1673, Test Acc=0.9400
# Epoch 135: Train Loss=0.1388, Train Acc=0.9680, Test Loss=0.1672, Test Acc=0.9400
# Epoch 136: Train Loss=0.1386, Train Acc=0.9680, Test Loss=0.1670, Test Acc=0.9400
# Epoch 137: Train Loss=0.1383, Train Acc=0.9680, Test Loss=0.1669, Test Acc=0.9400
# Epoch 138: Train Loss=0.1381, Train Acc=0.9680, Test Loss=0.1668, Test Acc=0.9400
# Epoch 139: Train Loss=0.1379, Train Acc=0.9680, Test Loss=0.1667, Test Acc=0.9400
# Epoch 140: Train Loss=0.1376, Train Acc=0.9680, Test Loss=0.1666, Test Acc=0.9400
# Epoch 141: Train Loss=0.1374, Train Acc=0.9680, Test Loss=0.1665, Test Acc=0.9400
# Epoch 142: Train Loss=0.1372, Train Acc=0.9680, Test Loss=0.1664, Test Acc=0.9400
# Epoch 143: Train Loss=0.1370, Train Acc=0.9680, Test Loss=0.1663, Test Acc=0.9400
# Epoch 144: Train Loss=0.1368, Train Acc=0.9680, Test Loss=0.1662, Test Acc=0.9400
# Epoch 145: Train Loss=0.1365, Train Acc=0.9680, Test Loss=0.1662, Test Acc=0.9400
# Epoch 146: Train Loss=0.1363, Train Acc=0.9680, Test Loss=0.1661, Test Acc=0.9400
# Epoch 147: Train Loss=0.1361, Train Acc=0.9680, Test Loss=0.1660, Test Acc=0.9400
# Epoch 148: Train Loss=0.1359, Train Acc=0.9680, Test Loss=0.1659, Test Acc=0.9400
# Epoch 149: Train Loss=0.1357, Train Acc=0.9680, Test Loss=0.1658, Test Acc=0.9400
# Epoch 150: Train Loss=0.1355, Train Acc=0.9680, Test Loss=0.1657, Test Acc=0.9400
# Epoch 151: Train Loss=0.1353, Train Acc=0.9700, Test Loss=0.1656, Test Acc=0.9400
# Epoch 152: Train Loss=0.1351, Train Acc=0.9700, Test Loss=0.1655, Test Acc=0.9400
# Epoch 153: Train Loss=0.1349, Train Acc=0.9700, Test Loss=0.1655, Test Acc=0.9400
# Epoch 154: Train Loss=0.1347, Train Acc=0.9700, Test Loss=0.1654, Test Acc=0.9400
# Epoch 155: Train Loss=0.1345, Train Acc=0.9700, Test Loss=0.1653, Test Acc=0.9400
# Epoch 156: Train Loss=0.1343, Train Acc=0.9700, Test Loss=0.1652, Test Acc=0.9400
# Epoch 157: Train Loss=0.1341, Train Acc=0.9700, Test Loss=0.1652, Test Acc=0.9400
# Epoch 158: Train Loss=0.1339, Train Acc=0.9700, Test Loss=0.1651, Test Acc=0.9400
# Epoch 159: Train Loss=0.1338, Train Acc=0.9700, Test Loss=0.1650, Test Acc=0.9400
# Epoch 160: Train Loss=0.1336, Train Acc=0.9700, Test Loss=0.1649, Test Acc=0.9400
# Epoch 161: Train Loss=0.1334, Train Acc=0.9700, Test Loss=0.1649, Test Acc=0.9450
# Epoch 162: Train Loss=0.1332, Train Acc=0.9700, Test Loss=0.1648, Test Acc=0.9450
# Epoch 163: Train Loss=0.1330, Train Acc=0.9700, Test Loss=0.1647, Test Acc=0.9450
# Epoch 164: Train Loss=0.1329, Train Acc=0.9700, Test Loss=0.1647, Test Acc=0.9450
# Epoch 165: Train Loss=0.1327, Train Acc=0.9700, Test Loss=0.1646, Test Acc=0.9450
# Epoch 166: Train Loss=0.1325, Train Acc=0.9700, Test Loss=0.1645, Test Acc=0.9450
# Epoch 167: Train Loss=0.1323, Train Acc=0.9700, Test Loss=0.1645, Test Acc=0.9450
# Epoch 168: Train Loss=0.1322, Train Acc=0.9700, Test Loss=0.1644, Test Acc=0.9450
# Epoch 169: Train Loss=0.1320, Train Acc=0.9700, Test Loss=0.1643, Test Acc=0.9450
# Epoch 170: Train Loss=0.1318, Train Acc=0.9700, Test Loss=0.1643, Test Acc=0.9450
# Epoch 171: Train Loss=0.1317, Train Acc=0.9700, Test Loss=0.1642, Test Acc=0.9450
# Epoch 172: Train Loss=0.1315, Train Acc=0.9700, Test Loss=0.1642, Test Acc=0.9450
# Epoch 173: Train Loss=0.1313, Train Acc=0.9700, Test Loss=0.1641, Test Acc=0.9450
# Epoch 174: Train Loss=0.1312, Train Acc=0.9700, Test Loss=0.1640, Test Acc=0.9450
# Epoch 175: Train Loss=0.1310, Train Acc=0.9700, Test Loss=0.1640, Test Acc=0.9450
# Epoch 176: Train Loss=0.1309, Train Acc=0.9700, Test Loss=0.1639, Test Acc=0.9450
# Epoch 177: Train Loss=0.1307, Train Acc=0.9700, Test Loss=0.1639, Test Acc=0.9450
# Epoch 178: Train Loss=0.1305, Train Acc=0.9700, Test Loss=0.1638, Test Acc=0.9450
# Epoch 179: Train Loss=0.1304, Train Acc=0.9700, Test Loss=0.1638, Test Acc=0.9450
# Epoch 180: Train Loss=0.1302, Train Acc=0.9700, Test Loss=0.1637, Test Acc=0.9450
# Epoch 181: Train Loss=0.1301, Train Acc=0.9700, Test Loss=0.1637, Test Acc=0.9450
# Epoch 182: Train Loss=0.1299, Train Acc=0.9700, Test Loss=0.1636, Test Acc=0.9450
# Epoch 183: Train Loss=0.1298, Train Acc=0.9700, Test Loss=0.1636, Test Acc=0.9450
# Epoch 184: Train Loss=0.1296, Train Acc=0.9700, Test Loss=0.1635, Test Acc=0.9450
# Epoch 185: Train Loss=0.1295, Train Acc=0.9700, Test Loss=0.1635, Test Acc=0.9450
# Epoch 186: Train Loss=0.1293, Train Acc=0.9700, Test Loss=0.1634, Test Acc=0.9450
# Epoch 187: Train Loss=0.1292, Train Acc=0.9700, Test Loss=0.1634, Test Acc=0.9450
# Epoch 188: Train Loss=0.1291, Train Acc=0.9700, Test Loss=0.1634, Test Acc=0.9450
# Epoch 189: Train Loss=0.1289, Train Acc=0.9700, Test Loss=0.1633, Test Acc=0.9450
# Epoch 190: Train Loss=0.1288, Train Acc=0.9720, Test Loss=0.1633, Test Acc=0.9450
# Epoch 191: Train Loss=0.1286, Train Acc=0.9720, Test Loss=0.1632, Test Acc=0.9450
# Epoch 192: Train Loss=0.1285, Train Acc=0.9720, Test Loss=0.1632, Test Acc=0.9450
# Epoch 193: Train Loss=0.1284, Train Acc=0.9720, Test Loss=0.1632, Test Acc=0.9450
# Epoch 194: Train Loss=0.1282, Train Acc=0.9700, Test Loss=0.1631, Test Acc=0.9450
# Epoch 195: Train Loss=0.1281, Train Acc=0.9700, Test Loss=0.1631, Test Acc=0.9450
# Epoch 196: Train Loss=0.1280, Train Acc=0.9700, Test Loss=0.1630, Test Acc=0.9450
# Epoch 197: Train Loss=0.1278, Train Acc=0.9700, Test Loss=0.1630, Test Acc=0.9450
# Epoch 198: Train Loss=0.1277, Train Acc=0.9700, Test Loss=0.1630, Test Acc=0.9450
# Epoch 199: Train Loss=0.1276, Train Acc=0.9700, Test Loss=0.1629, Test Acc=0.9450
# Epoch 200: Train Loss=0.1275, Train Acc=0.9700, Test Loss=0.1629, Test Acc=0.9450

# %%
# plot training and testing losses
plt.plot(np.arange(epochs), np.array(train_losses), label="Train")
plt.plot(np.arange(epochs), np.array(test_losses), label="Test")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('Train and Test Loss - Implemetation with Pytorch')
plt.legend()
plt.savefig('nn_pytorch_loss.png')
plt.show()

# plot training and testing accuracies
plt.plot(np.arange(epochs), np.array(train_accs), label="Train")
plt.plot(np.arange(epochs), np.array(test_accs), label="Test")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title('Train and Test Accuracy  - Implemetation with Pytorch')
plt.legend()
plt.savefig('nn_pytorch_acc.png')
plt.show()
